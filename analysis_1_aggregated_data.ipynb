# %%
import pandas as pd

# %%
data_trans = pd.read_csv("data/aggregated_data.csv")
data_demo = pd.read_csv("data/demographics")
# Out:
# /home/superyang713/Environments/sharpestmind/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_trans.head()
# Out:
#   PostalCd   Count      Sum  Min   Max       Mean        Std
# 0   A0A0A0    17.0    293.0  1.0  56.0  17.235294  14.320000
# 1   A0A1A0   102.0   1434.0  1.0  58.0  14.058824  10.263151
# 2   A0A1B0   606.0   7318.0  1.0  55.0  12.075908   9.532918
# 3   A0A1C0  1291.0  17233.0  1.0  62.0  13.348567  10.083688
# 4   A0A1E0   353.0   4861.0  1.0  59.0  13.770538   9.747276

# %%
data_trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450090 entries, 0 to 450089
# Data columns (total 7 columns):
# PostalCd    450090 non-null object
# Count       450090 non-null float64
# Sum         450090 non-null float64
# Min         450090 non-null float64
# Max         450090 non-null float64
# Mean        450090 non-null float64
# Std         450090 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 24.0+ MB

# %%
data_trans.hist(bins=100, figsize=(12,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb5bff50160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb5bfced470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb5bfc84240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb5bfc58588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fb5bfc06b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb5bfbc3128>]],
#       dtype=object)

# %% [markdown]
# ## Explore demographics data

# %%
data_demo.head(100)
# Out:
#           ID PostCode           Demographics       Ethnicity  \
# 0   E1V6V5-0   E1V6V5  25 to 29 years-Female  North American
# 1   E1V6V5-1   E1V6V5    45 to 49 years-Male         British
# 2   A0A0B7-0   A0A0B7  30 to 34 years-Female         British
# 3   A0A0B7-1   A0A0B7    35 to 39 years-Male  North American
# 4   E4T0C1-0   E4T0C1  60 to 64 years-Female  North American
# ..       ...      ...                    ...             ...
# 95  H1M2G4-1   H1M2G4  20 to 24 years-Female  North American
# 96  H1M2G4-2   H1M2G4  25 to 29 years-Female          French
# 97  H1M2G4-3   H1M2G4  25 to 29 years-Female  North American
# 98  H1M2G4-4   H1M2G4  30 to 34 years-Female  North American
# 99  H1M2G4-5   H1M2G4  30 to 34 years-Female  Middle Eastern
#
#                     Religion                           Language  \
# 0                  Christian                            English
# 1                  Christian                             French
# 2                  Christian  English and non-official language
# 3                  Christian  English and non-official language
# 4                  Christian                             French
# ..                       ...                                ...
# 95                 Christian                             French
# 96  No religious affiliation                             French
# 97  No religious affiliation              Non-official language
# 98                 Christian                            English
# 99                    Muslim              Non-official language
#
#        Immigration                           Commute     Marital Status  \
# 0   Non-immigrants     Car, truck, van - as a driver            Married
# 1   Non-immigrants     Car, truck, van - as a driver            Married
# 2   Non-immigrants     Car, truck, van - as a driver            Married
# 3   Non-immigrants     Car, truck, van - as a driver            Married
# 4   Non-immigrants     Car, truck, van - as a driver            Married
# ..             ...                               ...                ...
# 95  Non-immigrants     Car, truck, van - as a driver      Never married
# 96  Non-immigrants     Car, truck, van - as a driver  Living common law
# 97  Non-immigrants     Car, truck, van - as a driver  Living common law
# 98  Non-immigrants  Car, truck, van - as a passenger  Living common law
# 99      Immigrants                    Public transit      Never married
#
#    Family Size               Dwelling Ownership         Education  \
# 0     1 person  Single-detached house     Owned     Postsecondary
# 1    2 persons  Single-detached house     Owned     Postsecondary
# 2     1 person  Single-detached house     Owned           College
# 3    2 persons  Single-detached house     Owned     Postsecondary
# 4    2 persons  Single-detached house     Owned  Secondary school
# ..         ...                    ...       ...               ...
# 95   4 persons                  Other    Rented     Postsecondary
# 96   2 persons                  Other     Owned     Postsecondary
# 97   2 persons                  Other     Owned     Postsecondary
# 98   2 persons                  Other     Owned     Postsecondary
# 99    1 person                  Other    Rented     Postsecondary
#
#                                            Profession  Income Family Income
# 0                62 Health care and social assistance   34560        150658
# 1   56 Administrative and support, waste managemen...   57785         78950
# 2                                 31-33 Manufacturing   44055        111262
# 3                                  44-45 Retail trade   35954         64925
# 4    21 Mining, quarrying, and oil and gas extraction   59829        154926
# ..                                                ...     ...           ...
# 95                                 44-45 Retail trade    7385         78838
# 96                                 44-45 Retail trade   44743         46280
# 97               62 Health care and social assistance   23024         34038
# 98                 72 Accommodation and food services   30602         12496
# 99               62 Health care and social assistance    2800         12948
#
# [100 rows x 16 columns]

# %%
data_demo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29115181 entries, 0 to 29115180
# Data columns (total 16 columns):
# ID                object
# PostCode          object
# Demographics      object
# Ethnicity         object
# Religion          object
# Language          object
# Immigration       object
# Commute           object
# Marital Status    object
# Family Size       object
# Dwelling          object
# Ownership         object
# Education         object
# Profession        object
# Income            int64
# Family Income     object
# dtypes: int64(1), object(15)
# memory usage: 3.5+ GB

# %%
data_demo.Religion.unique()
# Out:
# array(['Christian', 'No religious affiliation', 'Muslim', 'Buddhist',
#        'Traditional (Aboriginal) Spirituality', 'Hindu', 'Jewish',
#        'Other religions', 'Sikh'], dtype=object)

# %%
data_demo.Ethnicity.unique()
# Out:
# array(['North American', 'British', 'French', 'Western European',
#        'Latin, Central and South American', 'Eastern European',
#        'Aboriginal', 'Other European origins', 'Southern European',
#        'Middle Eastern', 'African', 'Chinese', 'Caribbean', 'Oceania',
#        'Northern European', 'Vietnamese', 'South Asian', 'Malaysian',
#        'Korean', 'Japanese', 'Filipino', 'Indonesian'], dtype=object)

# %%
data_demo.Demographics.unique()
# Out:
# array(['25 to 29 years-Female', '45 to 49 years-Male',
#        '30 to 34 years-Female', '35 to 39 years-Male',
#        '60 to 64 years-Female', '65 years and over-Female',
#        '20 to 24 years-Female', '35 to 39 years-Female',
#        '40 to 44 years-Female', '45 to 49 years-Female',
#        '50 to 54 years-Female', '55 to 59 years-Female',
#        '20 to 24 years-Male', '25 to 29 years-Male',
#        '30 to 34 years-Male', '40 to 44 years-Male',
#        '50 to 54 years-Male', '55 to 59 years-Male',
#        '60 to 64 years-Male', '65 years and over-Male'], dtype=object)

# %%
data_demo.Language.unique()
# Out:
# array(['English', 'French', 'English and non-official language',
#        'Non-official language',
#        'English, French and non-official language', 'English and French',
#        'French and non-official language'], dtype=object)

# %%
data_demo.Immigration.unique()
# Out:
# array(['Non-immigrants', 'Immigrants'], dtype=object)

# %%
data_demo.Commute.unique()
# Out:
# array(['Car, truck, van - as a driver',
#        'Car, truck, van - as a passenger', 'Public transit',
#        'Other method', 'Walked', 'Bicycle'], dtype=object)

# %%
data_demo["Marital Status"].unique()
# Out:
# array(['Married', 'Living common law', 'Never married', 'Separated',
#        'Divorced', 'Widowed'], dtype=object)

# %%
data_demo["Family Size"].unique()
# Out:
# array(['1 person', '2 persons', '4 persons', '5 or more persons',
#        '3 persons'], dtype=object)

# %%
data_demo.Dwelling.unique()
# Out:
# array(['Single-detached house', 'Other', 'Apartment'], dtype=object)

# %%
data_demo.Ownership.unique()
# Out:
# array(['Owned', 'Rented', 'Band housing'], dtype=object)

# %%
data_demo.Education.unique()
# Out:
# array(['Postsecondary', 'College', 'Secondary school', "Master's degree",
#        "Bachelor's degree", 'No certificate, diploma or degree',
#        'Doctorate', 'Degree in medicine & related'], dtype=object)

# %%
data_demo.Profession.unique()
# Out:
# array(['62 Health care and social assistance',
#        '56 Administrative and support, waste management and remediation services',
#        '31-33 Manufacturing', '44-45 Retail trade',
#        '21 Mining, quarrying, and oil and gas extraction',
#        '61 Educational services',
#        '81 Other services (except public administration)',
#        '72 Accommodation and food services',
#        '53 Real estate and rental and leasing',
#        '54 Professional, scientific and technical services',
#        '11 Agriculture, forestry, fishing and hunting',
#        '51 Information and cultural industries', '41 Wholesale trade',
#        '22 Utilities', '52 Finance and insurance', '23 Construction',
#        '91 Public administration', '48-49 Transportation and warehousing',
#        '71 Arts, entertainment and recreation',
#        '55 Management of companies and enterprises'], dtype=object)
