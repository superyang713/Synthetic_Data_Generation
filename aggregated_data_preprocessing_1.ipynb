# %% [markdown]
# # The purpose of this notebook is to explore the original dataset, and remove some unnecessary colomns and scale down the size of the file as much as possible to make it fit into a computer ram.

# %%
import dask.dataframe as dd
import numpy as np

# %%
dtype = {'CivicNumStop': 'object', "ClusterId": np.int32, "BoxUnitNumStop": np.float64}
df = dd.read_csv("../Data_TransUnion/trans.csv", encoding = "ISO-8859-1", dtype=dtype)
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.25 µs

# %%
df.head()
# Out:
# /home/superyang713/Environments/sharpestmind/lib/python3.7/site-packages/dask/core.py:118: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   args2 = [_execute_task(a, cache) for a in args]
#    ClusterId PostalCd  SubdivisionNum    StreetNm  CityNm ProvCd  \
# 0   10000289   A1K0G2               1  SPRUCEWOOD  TORBAY     NL
# 1   10000289   A1K0G2               1  SPRUCEWOOD  TORBAY     NL
# 2   10000289   A1K0G2               1  SPRUCEWOOD  TORBAY     NL
# 3   10000289   A1K0G2               1  SPRUCEWOOD  TORBAY     NL
# 4   10000289   A1K0G2               1  SPRUCEWOOD  TORBAY     NL
#
#   CivicNumStart BoxUnitNumStart CivicNumStop  BoxUnitNumStop  ConsumerQty  \
# 0             2               0           14             0.0           22
# 1             2               0           14             0.0           22
# 2             2               0           14             0.0           22
# 3             2               0           14             0.0           22
# 4             2               0           14             0.0           22
#
#   IndustryCategory  IndustryVariableNum  Count   Sum  Min   Max    Mean  \
# 0               AT                    1     21   307    2    35   14.62
# 1               AT                    2     20    69    1     8    3.45
# 2               BC                   60     17  2416   10   828  142.12
# 3               BR                   60     17  3419   10  1428  201.12
# 4               BR                   85      4   185   33    61   46.25
#
#    Median  StdDev
# 0    11.0   10.02
# 1     3.0    2.09
# 2    28.0  254.83
# 3   110.0  365.04
# 4    45.5   11.64

# %%
df = df.loc[(df["IndustryCategory"] == "AT") & (df["IndustryVariableNum"] == 1)]

# %%
df.head(20)
# Out:
# /home/superyang713/Environments/sharpestmind/lib/python3.7/site-packages/dask/core.py:118: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   args2 = [_execute_task(a, cache) for a in args]
#       ClusterId PostalCd  SubdivisionNum          StreetNm  \
# 0      10000289   A1K0G2               1        SPRUCEWOOD
# 15     10000296   A1K1C7               2            ADAM'S
# 29     10000342   A1N1A7               1         SMALLWOOD
# 30     10000458   A2H2K9               1             NORTH
# 46     10000596   B0E1A0              21           HIGHWAY
# 58     10000046   A0G3B0               8              MAIN
# 61     10000063   A0G3K0               5            BOX 41
# 75     10000610   B0E1A0              35        PO BOX 151
# 78     10000691   B0N2A0              35           BELMONT
# 86     10000698   B0N2A0              42            COUNTY
# 100    10000707   B0N2A0              51           HIGHWAY
# 110    10000735   B0N2A0              79          LAKEWOOD
# 4137   10000069   A0G3K0              11              MAIN
# 4150   10000740   B0N2A0              84             MCKAY
# 4156   10000196   A1B2P9               1         CARPASIAN
# 4160   10000747   B0N2A0              91      NEW CHEVERIE
# 4172   10000067   A0G3K0               9  GENERAL DELIVERY
# 4174   10000083   A0G3X0               3           GENERAL
# 4183   10000129   A0K5C0               1               # 1
# 4193   10000180   A1A5P4               1         TURNBERRY
#
#                      CityNm ProvCd CivicNumStart BoxUnitNumStart CivicNumStop  \
# 0                    TORBAY     NL             2               0           14
# 15                 FLATROCK     NL            26               0          624
# 29              MOUNT PEARL     NL           10A               A           22
# 30             CORNER BROOK     NL           31A               0           17
# 46                  ARICHAT     NS           933               0         2868
# 58         LITTLE BURNT BAY     NL           120               G          218
# 61    COMFORT COVE-NEWSTEAD     NL            3B               0           39
# 75                  ARICHAT     NS             0               0            0
# 78                  NEWPORT     NS           200               R         2176
# 86                  NEWPORT     NS            26               P         1052
# 100                 NEWPORT     NS          2754             215         3718
# 110                 NEWPORT     NS             1               R          250
# 4137  COMFORT COVE-NEWSTEAD     NL            51            MAIN          342
# 4150                NEWPORT     NS           164               0          759
# 4156             ST. JOHN'S     NL            29               C           43
# 4160                NEWPORT     NS          1693               0         2133
# 4172       COMFORT COVE-NEW     NL           27A               0           95
# 4174                SALVAGE     NL           60C               A           85
# 4183             SANDY COVE     NL             0               0          136
# 4193             ST. JOHN'S     NL            17               0           27
#
#       BoxUnitNumStop  ConsumerQty IndustryCategory  IndustryVariableNum  \
# 0                0.0           22               AT                    1
# 15               0.0           15               AT                    1
# 29               0.0           23               AT                    1
# 30               0.0           18               AT                    1
# 46            2345.0           15               AT                    1
# 58               0.0           15               AT                    1
# 61               0.0           15               AT                    1
# 75               0.0           15               AT                    1
# 78               0.0           15               AT                    1
# 86               0.0           15               AT                    1
# 100            215.0           16               AT                    1
# 110              2.0           15               AT                    1
# 4137             0.0           15               AT                    1
# 4150             6.0           15               AT                    1
# 4156             0.0           21               AT                    1
# 4160             1.0           15               AT                    1
# 4172             0.0           15               AT                    1
# 4174             0.0           15               AT                    1
# 4183             0.0           15               AT                    1
# 4193             0.0           15               AT                    1
#
#       Count  Sum  Min  Max   Mean  Median  StdDev
# 0        21  307    2   35  14.62    11.0   10.02
# 15       15  241    5   51  16.07    14.0   10.87
# 29       22  250    1   25  11.36    11.0    7.35
# 30       17  234    3   38  13.77    12.0    8.82
# 46       14  188    1   32  13.43    12.0    9.06
# 58       15  179    1   26  11.93    15.0    9.45
# 61       15  141    1   22   9.40     7.0    7.32
# 75       15  163    1   40  10.87     7.0   11.33
# 78       14  170    3   26  12.14    11.5    6.71
# 86       14  184    2   28  13.14    11.5    8.69
# 100      13  145    2   47  11.15     8.0   11.65
# 110      15  162    1   24  10.80    12.0    8.00
# 4137     15  157    1   24  10.47     7.0    7.56
# 4150     15  159    1   34  10.60     8.0    8.67
# 4156     20  286    1   34  14.30    14.0   11.13
# 4160     15  126    1   35   8.40     4.0   10.62
# 4172     15  182    1   30  12.13    12.0    7.81
# 4174     15  222    4   27  14.80    16.0    7.36
# 4183     15  254    2   28  16.93    16.0    6.95
# 4193     14  106    1   22   7.57     6.5    7.36

# %%
useless_columns = [
    "ClusterId",
    "SubdivisionNum", 
    "StreetNm", 
    "CityNm", 
    "ProvCd",
    "CivicNumStart", 
    "BoxUnitNumStart",
    "CivicNumStop", 
    "BoxUnitNumStop", 
    "ConsumerQty"
]

df = df.drop(useless_columns, axis=1)

# %%
df.head()
# Out:
# /home/superyang713/Environments/sharpestmind/lib/python3.7/site-packages/dask/core.py:118: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   args2 = [_execute_task(a, cache) for a in args]
#   PostalCd IndustryCategory  IndustryVariableNum  Count   Sum  Min   Max  \
# 0   A1K0G2               AT                    1     21   307    2    35
# 1   A1K0G2               AT                    2     20    69    1     8
# 2   A1K0G2               BC                   60     17  2416   10   828
# 3   A1K0G2               BR                   60     17  3419   10  1428
# 4   A1K0G2               BR                   85      4   185   33    61
#
#      Mean  Median  StdDev
# 0   14.62    11.0   10.02
# 1    3.45     3.0    2.09
# 2  142.12    28.0  254.83
# 3  201.12   110.0  365.04
# 4   46.25    45.5   11.64

# %%
df.info()
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 10 entries, PostalCd to StdDev
# dtypes: object(2), float64(3), int64(5)

# %%
df = df.loc[(df["IndustryCategory"] == "AT") & (df["IndustryVariableNum"] == 1)]

# %%
df.head()
# Out:
# /home/superyang713/Environments/sharpestmind/lib/python3.7/site-packages/dask/core.py:118: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   args2 = [_execute_task(a, cache) for a in args]
#    PostalCd IndustryCategory  IndustryVariableNum  Count  Sum  Min  Max  \
# 0    A1K0G2               AT                    1     21  307    2   35
# 15   A1K1C7               AT                    1     15  241    5   51
# 29   A1N1A7               AT                    1     22  250    1   25
# 30   A2H2K9               AT                    1     17  234    3   38
# 46   B0E1A0               AT                    1     14  188    1   32
#
#      Mean  Median  StdDev
# 0   14.62    11.0   10.02
# 15  16.07    14.0   10.87
# 29  11.36    11.0    7.35
# 30  13.77    12.0    8.82
# 46  13.43    12.0    9.06

# %%
df.describe()
# Out:
# Dask DataFrame Structure:
#               IndustryVariableNum    Count      Sum      Min      Max     Mean   Median   StdDev
# npartitions=1
#                           float64  float64  float64  float64  float64  float64  float64  float64
#                               ...      ...      ...      ...      ...      ...      ...      ...
# Dask Name: describe-numeric, 27028 tasks

# %%
df = df.drop(["IndustryCategory", "IndustryVariableNum"], axis=1)

# %%
df.head()
# Out:
# /home/superyang713/Environments/sharpestmind/lib/python3.7/site-packages/dask/core.py:118: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   args2 = [_execute_task(a, cache) for a in args]
#    PostalCd  Count  Sum  Min  Max   Mean  Median  StdDev
# 0    A1K0G2     21  307    2   35  14.62    11.0   10.02
# 15   A1K1C7     15  241    5   51  16.07    14.0   10.87
# 29   A1N1A7     22  250    1   25  11.36    11.0    7.35
# 30   A2H2K9     17  234    3   38  13.77    12.0    8.82
# 46   B0E1A0     14  188    1   32  13.43    12.0    9.06

# %%
df = df.compute()
# Out:
# /home/superyang713/Environments/sharpestmind/lib/python3.7/site-packages/dask/core.py:118: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   args2 = [_execute_task(a, cache) for a in args]
# /home/superyang713/Environments/sharpestmind/lib/python3.7/site-packages/dask/core.py:118: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   args2 = [_execute_task(a, cache) for a in args]

# %%
df.head()
# Out:
#    PostalCd  Count  Sum  Min  Max   Mean  Median  StdDev
# 0    A1K0G2     21  307    2   35  14.62    11.0   10.02
# 15   A1K1C7     15  241    5   51  16.07    14.0   10.87
# 29   A1N1A7     22  250    1   25  11.36    11.0    7.35
# 30   A2H2K9     17  234    3   38  13.77    12.0    8.82
# 46   B0E1A0     14  188    1   32  13.43    12.0    9.06

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_csv("number_of_trade.csv", index=False)
